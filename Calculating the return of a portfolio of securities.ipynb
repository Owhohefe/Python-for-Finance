# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ["PG", "MSFT", "F", "GE"]
mydata = pd.DataFrame()
for t in tickers:
    mydata[t]=wb.DataReader(t, data_source = "yahoo", start="1995-1-1")["Adj Close"]

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6576 entries, 1995-01-03 to 2021-02-12
# Data columns (total 4 columns):
# PG      6576 non-null float64
# MSFT    6576 non-null float64
# F       6576 non-null float64
# GE      6576 non-null float64
# dtypes: float64(4)
# memory usage: 256.9 KB

# %%
mydata.head()
# Out:
#                   PG      MSFT         F        GE
# Date
# 1995-01-03  8.166473  2.394761  4.380183  4.122630
# 1995-01-04  8.101009  2.412169  4.498034  4.122630
# 1995-01-05  7.986450  2.372380  4.458752  4.132737
# 1995-01-06  8.002816  2.412169  4.458752  4.112525
# 1995-01-09  7.970086  2.397249  4.537320  4.072110

# %%
mydata.tail()
# Out:
#                     PG        MSFT      F     GE
# Date
# 2021-02-08  129.169998  242.470001  11.56  11.61
# 2021-02-09  128.669998  243.770004  11.93  11.54
# 2021-02-10  128.220001  242.820007  11.76  11.40
# 2021-02-11  128.330002  244.490005  11.45  11.46
# 2021-02-12  127.620003  244.990005  11.45  11.73

# %%
mydata.iloc[0]
# Out:
# PG      8.166473
# MSFT    2.394761
# F       4.380183
# GE      4.122630
# Name: 1995-01-03 00:00:00, dtype: float64

# %%
(mydata/mydata.iloc[0]*100).plot(figsize=(15,6))

# %%
mydata.plot(figsize=(15,6))

# %%
returns = (mydata/mydata.shift(1))-1
returns
# Out:
#                   PG      MSFT         F        GE
# Date
# 1995-01-03       NaN       NaN       NaN       NaN
# 1995-01-04 -0.008016  0.007269  0.026905  0.000000
# 1995-01-05 -0.014141 -0.016495 -0.008733  0.002452
# 1995-01-06  0.002049  0.016772  0.000000 -0.004891
# 1995-01-09 -0.004090 -0.006186  0.017621 -0.009827
# 1995-01-10  0.012321  0.012448 -0.017316  0.007444
# 1995-01-11 -0.002029  0.006148  0.000000  0.014778
# 1995-01-12  0.010163 -0.002037 -0.008811 -0.002428
# 1995-01-13  0.011736  0.024490  0.017777  0.012166
# 1995-01-16  0.008000  0.021913  0.013101  0.012019
# 1995-01-17  0.003968  0.007797 -0.008620 -0.011876
# 1995-01-18 -0.021739  0.006769 -0.017391  0.004808
# 1995-01-19 -0.004040 -0.024015 -0.026549 -0.023924
# 1995-01-20 -0.004057 -0.029527 -0.040909  0.000000
# 1995-01-23  0.010184  0.019269 -0.004740 -0.014705
# 1995-01-24 -0.002016 -0.012686 -0.009234  0.002487
# 1995-01-25  0.014141 -0.004283  0.014563  0.007444
# 1995-01-26  0.003985 -0.030365 -0.028708  0.004926
# 1995-01-27  0.027777  0.000000  0.000000 -0.009804
# 1995-01-30  0.015444 -0.014613 -0.024631  0.012377
# 1995-01-31 -0.009505  0.006355  0.020202  0.007335
# 1995-02-01 -0.019194 -0.004210 -0.004950 -0.007281
# 1995-02-02  0.007828 -0.002114  0.019900  0.002445
# 1995-02-03  0.009709  0.019068  0.004878  0.017073
# 1995-02-06  0.023077  0.012473 -0.004854 -0.002398
# 1995-02-07 -0.001880  0.002054 -0.009756  0.000000
# 1995-02-08 -0.011300  0.014344  0.004925  0.000000
# 1995-02-09 -0.001904  0.000000 -0.009804  0.004808
# 1995-02-10 -0.001909  0.002020  0.024753 -0.002392
# 1995-02-13  0.007648  0.000000 -0.004831  0.009592
# ...              ...       ...       ...       ...
# 2020-12-31  0.009944  0.003338 -0.007901  0.008403
# 2021-01-04 -0.009487 -0.021266 -0.030717 -0.030556
# 2021-01-05  0.006385  0.000965  0.015258  0.028653
# 2021-01-06  0.010526 -0.025929  0.021965  0.054782
# 2021-01-07 -0.009346  0.028457  0.024887 -0.007922
# 2021-01-08 -0.000432  0.006093 -0.006623  0.006211
# 2021-01-11 -0.006773 -0.009699  0.033333  0.009700
# 2021-01-12 -0.005803 -0.011771  0.051613  0.028821
# 2021-01-13  0.001532  0.006560  0.000000 -0.017827
# 2021-01-14 -0.010637 -0.015346  0.039877  0.007779
# 2021-01-15 -0.007511 -0.001737 -0.033432 -0.028302
# 2021-01-19 -0.008755  0.017823  0.019329  0.008826
# 2021-01-20 -0.012500  0.036500  0.083832 -0.003500
# 2021-01-21 -0.000984  0.002808  0.061694 -0.028095
# 2021-01-22 -0.007709  0.004356 -0.000867  0.003613
# 2021-01-25  0.017231  0.015844 -0.019965 -0.010801
# 2021-01-26  0.006428  0.012199 -0.008857  0.027298
# 2021-01-27 -0.035390  0.002453 -0.035746  0.007972
# 2021-01-28  0.015423  0.025891 -0.006487 -0.025483
# 2021-01-29 -0.016493 -0.029172 -0.017724 -0.036970
# 2021-02-01  0.005928  0.033152  0.028490  0.005618
# 2021-02-02 -0.001396 -0.000584  0.002770  0.046555
# 2021-02-03  0.001242  0.014571  0.031308 -0.003559
# 2021-02-04  0.000620 -0.004074  0.015179  0.022321
# 2021-02-05  0.004185  0.000785  0.012313 -0.004367
# 2021-02-08 -0.003087  0.001115  0.004344  0.018421
# 2021-02-09 -0.003871  0.005362  0.032007 -0.006029
# 2021-02-10 -0.003497 -0.003897 -0.014250 -0.012132
# 2021-02-11  0.000858  0.006878 -0.026361  0.005263
# 2021-02-12 -0.005533  0.002045  0.000000  0.023560
#
# [6576 rows x 4 columns]

# %%
weights = np.array([0.25, 0.25, 0.25, 0.25])

# %%
np.dot(returns, weights)
# Out:
# array([        nan,  0.0065396 , -0.00922944, ..., -0.00844399,
#        -0.00334049,  0.00501816])

# %%
annual_returns = returns.mean()*250
annual_returns
# Out:
# PG      0.130096
# MSFT    0.225890
# F       0.116147
# GE      0.091060
# dtype: float64

# %%
np.dot(annual_returns, weights)
# Out:
# 0.14079842126369763

# %%
portfolio_return = str(round(np.dot(annual_returns, weights)*100,5))+"%"
portfolio_return
# Out:
# '14.07984%'
