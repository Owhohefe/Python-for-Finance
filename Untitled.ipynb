# %%
import numpy as np
import pandas as pd
#from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(r"C:\Users\oekpom\Desktop\SOP\price_list.xlsx", sheet_name='Sheet3')

# %%
data.head()
# Out:
#    Unnamed: 0   Unnamed: 1   Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        Date         FBNH      CADBURY      ACCESS       UACN       WEMA
# 1  21/12/2012    0.0082988 -0.000689417  0.00332042  -0.023763          0
# 2  24/12/2012  0.000635526            0           0          0          0
# 3  27/12/2012  -0.00254453            0           0          0          0
# 4  28/12/2012  -0.00510857            0           0          0  0.0392207
#
#   Unnamed: 6   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13  \
# 0      NAHCO  TANTALIZERS        NEM       NNFM  ...   RTBRISCOE   CILEASING
# 1 -0.0131211    -0.076961  0.0180185          0  ...  -0.0294139           0
# 2          0            0  0.0176996          0  ...   0.0366341           0
# 3  0.0168386            0          0          0  ...   0.0353394           0
# 4          0            0 -0.0357181          0  ...    0.040822           0
#
# ...

# %%
new_header = data.iloc[0] 

#data = data[1:] 

data.columns = new_header

# %%
data.head()
# Out:
# 0        Date         FBNH      CADBURY      ACCESS      UACN       WEMA  \
# 0        Date         FBNH      CADBURY      ACCESS      UACN       WEMA
# 1  21/12/2012    0.0082988 -0.000689417  0.00332042 -0.023763          0
# 2  24/12/2012  0.000635526            0           0         0          0
# 3  27/12/2012  -0.00254453            0           0         0          0
# 4  28/12/2012  -0.00510857            0           0         0  0.0392207
#
# 0      NAHCO  TANTALIZERS        NEM  NNFM  ...  RTBRISCOE  CILEASING  \
# 0      NAHCO  TANTALIZERS        NEM  NNFM  ...  RTBRISCOE  CILEASING
# 1 -0.0131211    -0.076961  0.0180185     0  ... -0.0294139          0
# 2          0            0  0.0176996     0  ...  0.0366341          0
# 3  0.0168386            0          0     0  ...  0.0353394          0
# 4          0            0 -0.0357181     0  ...   0.040822          0
#
# 0  MORISON      AIICO    DNMEYER    DIAMOND         GTB  BERGER         UBN  \
# ...

# %%
data = data.set_index("Date")

# %%
data.head()
# Out:
# 0                  FBNH      CADBURY      ACCESS      UACN       WEMA  \
# Date
# Date               FBNH      CADBURY      ACCESS      UACN       WEMA
# 21/12/2012    0.0082988 -0.000689417  0.00332042 -0.023763          0
# 24/12/2012  0.000635526            0           0         0          0
# 27/12/2012  -0.00254453            0           0         0          0
# 28/12/2012  -0.00510857            0           0         0  0.0392207
#
# 0               NAHCO  TANTALIZERS        NEM  NNFM    LONGMAN  ...  \
# Date                                                            ...
# Date            NAHCO  TANTALIZERS        NEM  NNFM    LONGMAN  ...
# 21/12/2012 -0.0131211    -0.076961  0.0180185     0  0.0047506  ...
# 24/12/2012          0            0  0.0176996     0          0  ...
# 27/12/2012  0.0168386            0          0     0          0  ...
# 28/12/2012          0            0 -0.0357181     0          0  ...
#
# ...

# %%
data1 = data.drop('Date')

# %%
data1.head()
# Out:
# 0                  FBNH      CADBURY      ACCESS      UACN       WEMA  \
# Date
# 21/12/2012    0.0082988 -0.000689417  0.00332042 -0.023763          0
# 24/12/2012  0.000635526            0           0         0          0
# 27/12/2012  -0.00254453            0           0         0          0
# 28/12/2012  -0.00510857            0           0         0  0.0392207
# 31/12/2012   0.00638164            0           0         0          0
#
# 0               NAHCO TANTALIZERS        NEM NNFM    LONGMAN  ...  RTBRISCOE  \
# Date                                                          ...
# 21/12/2012 -0.0131211   -0.076961  0.0180185    0  0.0047506  ... -0.0294139
# 24/12/2012          0           0  0.0176996    0          0  ...  0.0366341
# 27/12/2012  0.0168386           0          0    0          0  ...  0.0353394
# 28/12/2012          0           0 -0.0357181    0          0  ...   0.040822
# 31/12/2012          0           0          0    0          0  ...  0.0132452
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 21/12/2012 to 24/12/2013
# Data columns (total 21 columns):
# FBNH           250 non-null object
# CADBURY        250 non-null object
# ACCESS         250 non-null object
# UACN           250 non-null object
# WEMA           250 non-null object
# NAHCO          250 non-null object
# TANTALIZERS    250 non-null object
# NEM            250 non-null object
# NNFM           250 non-null object
# LONGMAN        250 non-null object
# PRESTIGE       250 non-null object
# RTBRISCOE      250 non-null object
# CILEASING      250 non-null object
# MORISON        250 non-null object
# AIICO          250 non-null object
# DNMEYER        250 non-null object
# DIAMOND        250 non-null object
# GTB            250 non-null object
# BERGER         250 non-null object
# UBN            250 non-null object
# ZENITH         250 non-null object
# dtypes: object(21)
# memory usage: 21.5+ KB

# %%
data1["FBNH"] = pd.to_numeric(data1["FBNH"])
# Out:
# C:\Users\oekpom\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 21/12/2012 to 24/12/2013
# Data columns (total 21 columns):
# FBNH           250 non-null float64
# CADBURY        250 non-null object
# ACCESS         250 non-null object
# UACN           250 non-null object
# WEMA           250 non-null object
# NAHCO          250 non-null object
# TANTALIZERS    250 non-null object
# NEM            250 non-null object
# NNFM           250 non-null object
# LONGMAN        250 non-null object
# PRESTIGE       250 non-null object
# RTBRISCOE      250 non-null object
# CILEASING      250 non-null object
# MORISON        250 non-null object
# AIICO          250 non-null object
# DNMEYER        250 non-null object
# DIAMOND        250 non-null object
# GTB            250 non-null object
# BERGER         250 non-null object
# UBN            250 non-null object
# ZENITH         250 non-null object
# dtypes: float64(1), object(20)
# memory usage: 22.5+ KB

# %%
header = ["FBNH","CADBURY","ACCESS","UACN","WEMA","NAHCO","TANTALIZERS","NEM","NNFM","LONGMAN","PRESTIGE","RTBRISCOE","CILEASING","MORISON","AIICO","DNMEYER","DIAMOND","GTB","BERGER","UBN","ZENITH"]
for h in header:
    data1[h] = pd.to_numeric(data1[h])
# Out:
# C:\Users\oekpom\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 21/12/2012 to 24/12/2013
# Data columns (total 21 columns):
# FBNH           250 non-null float64
# CADBURY        250 non-null float64
# ACCESS         250 non-null float64
# UACN           250 non-null float64
# WEMA           250 non-null float64
# NAHCO          250 non-null float64
# TANTALIZERS    250 non-null float64
# NEM            250 non-null float64
# NNFM           250 non-null float64
# LONGMAN        250 non-null float64
# PRESTIGE       250 non-null float64
# RTBRISCOE      250 non-null float64
# CILEASING      250 non-null float64
# MORISON        250 non-null float64
# AIICO          250 non-null float64
# DNMEYER        250 non-null float64
# DIAMOND        250 non-null float64
# GTB            250 non-null float64
# BERGER         250 non-null float64
# UBN            250 non-null float64
# ZENITH         250 non-null float64
# dtypes: float64(21)
# memory usage: 42.0+ KB

# %%
cov_matrix = data1.cov()
cov_matrix
# Out:
# 0                    FBNH       CADBURY        ACCESS          UACN  \
# 0
# FBNH         9.693242e-04 -8.526200e-04  4.513300e-04 -3.758594e-04
# CADBURY     -8.526200e-04  6.089736e-03 -2.016096e-04  3.139608e-03
# ACCESS       4.513300e-04 -2.016096e-04  1.139750e-03 -5.808441e-04
# UACN        -3.758594e-04  3.139608e-03 -5.808441e-04  3.157663e-03
# WEMA         6.670828e-04  4.859219e-03 -6.243114e-04  4.729942e-03
# NAHCO        4.601244e-04  2.780041e-04  9.399148e-04 -3.831885e-04
# TANTALIZERS -2.514529e-06  1.129100e-06 -9.595779e-07  7.892700e-06
# NEM          7.195445e-04  3.247729e-04  8.786347e-04 -1.158689e-04
# NNFM        -1.429449e-05  1.491237e-03  8.640037e-05  8.304391e-04
# LONGMAN      1.552153e-07 -6.969640e-08  5.923222e-08 -4.871957e-07
# PRESTIGE     4.506051e-04 -3.271922e-04  2.792430e-04 -1.872904e-04
# RTBRISCOE    1.110484e-03 -2.482394e-03  8.508895e-04 -1.783442e-03
# CILEASING    1.127525e-04 -2.733432e-04  2.747935e-05 -1.468679e-04
# ...

# %%
weights = np.array([0,0.041113002,0.198186371,0.001455058,0.096273662,0.224522367,0,0.000200941,0.014039035,0,0.0000788219543874859,0.328176956,0,0,0,0.095953786,0,0,0,0,0])

# %%
portfolio_variance = np.dot(weights.T, np.dot(data1.cov(), weights))
portfolio_variance
# Out:
# 0.0009988159378720425

# %%
portfolio_volatility = np.dot(weights.T, np.dot(data1.cov(), weights))**0.5
portfolio_volatility
# Out:
# 0.031604049390418984

# %%
print(str(round(portfolio_volatility,5)*100) +"%")
# Out:
# 3.16%

# %%
import math
Market_Value = 35639816.62
Confidence_Level = norm.ppf(0.99)
Holding_period = math.sqrt(10)

# %%
VaR_10_Days = Market_Value*portfolio_volatility*Confidence_Level*Holding_period
VaR_10_Days
# Out:
# 8286151.142880116

# %%
from scipy.stats import norm
f = norm.ppf(0.99)
print(f)
# Out:
# 2.3263478740408408
